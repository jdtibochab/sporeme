# %% [markdown]
# # Build community model

# %%
from __future__ import print_function, division, absolute_import

import sys

import qminospy
from qminospy.me2 import ME_NLP

# python imports
from copy import copy
import re
from os.path import join, dirname, abspath
import sys
from collections import defaultdict
import pickle

# third party imports
import pandas as pd
import cobra
from tqdm import tqdm
import numpy as np
import scipy

# COBRAme
import cobrame
from cobrame.util import building, mu, me_model_interface
from cobrame.io.json import save_json_me_model, save_reduced_json_me_model

# ECOLIme
import bacillusme
from bacillusme import (transcription, translation, flat_files, generics, formulas, compartments)
from bacillusme.util.helper_functions import *

import copy
# %load_ext autoreload
# %autoreload 2
ecoli_files = dirname(abspath(bacillusme.__file__))
plt.rcParams['svg.fonttype'] = 'none'
# Out:
# /home/jt/work/cobrapy-0.5.11/cobra/io/sbml3.py:24: UserWarning: Install lxml for faster SBML I/O
#   warn("Install lxml for faster SBML I/O")
# /home/jt/work/cobrapy-0.5.11/cobra/io/__init__.py:12: UserWarning: cobra.io.sbml requires libsbml
#   warn("cobra.io.sbml requires libsbml")
# /home/jt/work/cobrapy-0.5.11/cobra/__init__.py
# /home/jt/work/cobrame/cobrame/__init__.py
# /home/jt/work/sporeme/bacillusme/__init__.py

# %%
# with open(ecoli_files+'/me_models/solution.pickle', 'rb') as solution:
#     me = pickle.load(solution)
with open(ecoli_files+'/me_models/solution_spore.pickle', 'rb') as solution:
    spore = pickle.load(solution)

# %%
with open(ecoli_files+'/me_models/solution.pickle', 'rb') as solution:
    me = pickle.load(solution)

# %% [markdown]
# ## Create spore model

# %% [markdown]
# ### Change IDs (compartment _s)

# %%
# Metabolites
new_compartment = 's'
fix = []
for met in tqdm(spore.metabolites):
    if re.search('_[c,e]$',met.id):
        met.id = re.sub('c$',new_compartment,met.id)
    else:
        met.id = met.id+'_'+new_compartment
# Out:
# 100%|██████████| 3442/3442 [00:00<00:00, 774755.52it/s]

# %%
# Reactions
new_compartment = 's'
fix = []
for r in tqdm(spore.reactions):
        r.id = r.id+'_'+new_compartment
# Out:
# 100%|██████████| 5244/5244 [00:00<00:00, 1675931.89it/s]

# %%
spore.repair()

# %%
# Create new growth key for spore
new_growth_key = 'sigma'
for r in tqdm(spore.reactions):
    lb = r.lower_bound
    ub = r.upper_bound
    new_stoichiometry = {m:s for m,s in r.metabolites.items()}
    if hasattr(lb, 'subs'):
        growth_key = list(lb.free_symbols)[0]
        r.lower_bound = lb.subs(growth_key,new_growth_key)
    if hasattr(ub, 'subs'):
        growth_key = list(ub.free_symbols)[0]
        r.upper_bound = ub.subs(growth_key,new_growth_key)
    for m,s in new_stoichiometry.items():
        if hasattr(s, 'subs'):
            growth_key = list(s.free_symbols)[0]
            new_stoichiometry[m] = s.subs(growth_key,new_growth_key)
    r.add_metabolites(new_stoichiometry,combine=False)
# Out:
# 100%|██████████| 5244/5244 [00:06<00:00, 827.33it/s]

# %%
# Eliminate exchange reactions:
reactions = [r for r in spore.reactions]
for r in tqdm(reactions):
    if re.search('^EX_',r.id):
        r.remove_from_model()
# Out:
# 100%|██████████| 5244/5244 [00:00<00:00, 75998.68it/s]

# %% [markdown]
# ### Create spore biomass reactions

# %%
bio_rxn = spore.reactions.BIOMASS_BS_10_FWD_CPLX_dummy_s

# %%
bio_comp = pd.read_csv('spore_composition.csv',index_col=0)

# %%
# Identify lipid metabolites in biomass equation
lipid_demand = {}
for m in bio_comp.index:
    if '_BS_c' in m:
        new_id = re.sub('c$','s',m)
        value = bio_comp.loc[m]['coeff']
        lipid_demand[new_id] = abs(value)
                
for met, requirement in lipid_demand.items():
    component_mass = spore.metabolites.get_by_id(met).formula_weight / 1000.
    rxn = cobrame.SummaryVariable('Demand_' + met)
    spore.add_reactions([rxn])
    rxn.add_metabolites({met: -1 * requirement,
                         'lipid_biomass_s': component_mass * requirement})
    rxn.lower_bound = spore.reactions.biomass_dilution_s.lower_bound
    rxn.upper_bound = 1000.
#     print(rxn.reaction)

# %% [markdown]
# ### Merge

# %%
with open(ecoli_files+'/me_models/solution_mother.pickle', 'rb') as solution:
    sporeme = pickle.load(solution)

# %%
# Mother is not growing. Reactions should then be associated to sigma
new_growth_key = 'sigma'
for r in tqdm(sporeme.reactions):
    lb = r.lower_bound
    ub = r.upper_bound
    new_stoichiometry = {m:s for m,s in r.metabolites.items()}
    if hasattr(lb, 'subs'):
        growth_key = list(lb.free_symbols)[0]
        r.lower_bound = float(lb.subs(growth_key,0.))
    if hasattr(ub, 'subs'):
        growth_key = list(ub.free_symbols)[0]
        r.upper_bound = float(ub.subs(growth_key,1000.))
    for m,s in new_stoichiometry.items():
        if hasattr(s, 'subs'):
            growth_key = list(s.free_symbols)[0]
            new_stoichiometry[m] = s.subs(growth_key,new_growth_key)
            a = 1
    r.add_metabolites(new_stoichiometry,combine=False)
# Out:
# 100%|██████████| 6232/6232 [00:08<00:00, 741.04it/s]

# %%
# sporeme.add_reactions(spore.reactions) # This approach no longer worked after python version change.

# %% [markdown]
# #### Add spore reactions

# %%
# Add spore reactions
for r in tqdm(spore.reactions):
    new = r.__class__(r.id) # Create and identical reaction
    new.bounds = r.bounds
    sporeme.add_reaction(new)
    for k,v in r.metabolites.items():
        if not hasattr(sporeme.metabolites,k.id):
            args = k.__init__.__code__.co_varnames[1:] # Eliminate "self"
            if len(args) == 1: # No additional inputs to __init__
                met = k.__class__(k.id)
            else:
                vals = [getattr(k, dir(k)[[i.lower() for i in dir(k)].index(a)]) for a in args]
                met = k.__class__(*vals)
            sporeme.add_metabolites(met)
            met.name = k.name
            met.formula = k.formula
            met.charge = k.charge
            met.compartment = met.id[-1]
            
        new.add_metabolites({k.id:v})
# Out:
# 100%|██████████| 5013/5013 [00:03<00:00, 1548.83it/s]

# %% [markdown]
# #### Connect C with S
# Replace transport reaction S-E with S-C

# %%
# # Connect C with S
# ## Change spore transport from e-s to c-s

# ## DEPRECATED as this ignores transport reactions that change the metabolite chemically, such as PTS
# for m in tqdm(sporeme.metabolites):
#     if not isinstance(m,cobrame.Metabolite) or not re.search('_s$',m.id):
#         continue
#     in_transport = get_transport_reactions(sporeme,m.id,comps=['e','s'])
#     out_transport = get_transport_reactions(sporeme,m.id,comps=['s','e'])
#     transport_reactions = in_transport + out_transport
#     for r in transport_reactions:
#         old_met = sporeme.metabolites.get_by_id(re.sub('_s$','_e',m.id))
#         new_met = sporeme.metabolites.get_by_id(re.sub('_s$','_c',m.id))
#         coeff = r.metabolites[old_met]
#         r.add_metabolites({old_met:-coeff,new_met:coeff})

# %%
def get_compartments(rxn):
    return [m.compartment for m in rxn.metabolites if isinstance(m,cobrame.core.component.Metabolite)]

# %%
rxns = bacillusme.util.helper_functions.get_all_transport_of_model(sporeme)
rxns = set([r for r in rxns if isinstance(sporeme.reactions.get_by_id(r),cobrame.core.reaction.MetabolicReaction)])
for r in tqdm(rxns):
    rxn = sporeme.reactions.get_by_id(r)
    comps = get_compartments(rxn)
    if len(comps) < 2:
        continue
    if set(["e","s"]) - set(comps):
        continue
    
    for m,coeff in rxn.metabolites.items():
        # print(m)
        if m.compartment != "e":
            continue
        new_met_id = re.sub('_e$','_c',m.id)
        if new_met_id not in sporeme.metabolites:
            new_met = cobrame.core.component.Metabolite(new_met_id)
            sporeme.add_metabolites([new_met])
        new_met = sporeme.metabolites.get_by_id(new_met_id)
        rxn.add_metabolites({
            m : -coeff,
            new_met : coeff
        })
# Out:
# 100%|██████████| 11245/11245 [00:00<00:00, 595201.39it/s]
# 100%|██████████| 805/805 [00:00<00:00, 61034.25it/s]

# %%
# sporeme.objective = 'biomass_dilution_s'
sporeme.reactions.get_by_id('BIOMASS_BS_10_FWD_CPLX_dummy_s').upper_bound = 0

# %% [markdown]
# ### Correct spoIIIAA-H - spoIIQ formation

# %%
sporeme.reactions.get_by_id('formation_PORE-CPLX').remove_from_model()

# %%
old_formation = sporeme.reactions.get_by_id('formation_PORE-CPLX_s')

# %%
new_stoich = {}
for k,v in old_formation.metabolites.items():
    if v > 0 or 'BSU36550' in k.id: # spoIIQ is from the spore
        new_stoich[k] = v
        continue
    newk = k.id.split('_s')[0]
    new_stoich[sporeme.metabolites.get_by_id(newk)] = v

# %%
new_formation = cobrame.core.reaction.ComplexFormation('formation_combined_PORE-CPLX_s')
sporeme.add_reactions([new_formation])
new_formation.add_metabolites(new_stoich)
print(new_formation.reaction)
# Out:
# 12.0 protein_BSU24360_Inner_Membrane + 30.0 protein_BSU24370_Inner_Membrane + protein_BSU24380_Inner_Membrane + protein_BSU24390_Inner_Membrane + protein_BSU24400_Inner_Membrane + protein_BSU24410_Inner_Membrane + protein_BSU24420_Inner_Membrane + 6.0 protein_BSU24430_Inner_Membrane + 12.0 protein_BSU36550_Inner_Membrane_s --> PORE-CPLX_s

# %%
old_formation.remove_from_model()

# %%
sporeme.reactions.query('formation_.*PORE')
# Out:
# [<ComplexFormation formation_combined_PORE-CPLX_s at 0x7fecb03fe6d0>]

# %% [markdown]
# ### Peptidoglycan

# %% [markdown]
# ##### Spore peptidoglycan precursors are synthesized in the mother cell19 and are flipped across the outer forespore membrane into the intermembrane space by an as yet incompletely understood mechanism20.
# https://www.nature.com/articles/nrmicro2921
#
# Moreover, sigK is responsible for this biosynthesis activation, and it is an MC sigma factor. This makes sigK not essential in the FS anymore

# %%
r = sporeme.reactions.get_by_id('biomass_constituent_demand_s')
m = sporeme.metabolites.get_by_id('peptido_BS_s')
newm = sporeme.metabolites.get_by_id('peptido_BS_c')
r.add_metabolites({newm:r.metabolites[m],
                   m:-r.metabolites[m]})
r.metabolites
# Out:
# {<Metabolite 10fthf_s at 0x7fecb235be10>: -0.000367,
#  <Metabolite psetha_BS_s at 0x7fecb0bb3e50>: -0.00056,
#  <Constraint constituent_biomass_s at 0x7feca86b1250>: 0.13926027055704,
#  <Metabolite peptido_BS_c at 0x7feca91985d0>: -0.101817}

# %% [markdown]
# ### Close ATP synthase as there is no evidence for it on the spore membrane

# %%
for r in sporeme.reactions.query('ATPS.*_s'):
    print(r.id,r.reaction)
    r.bounds = (0,0)
# sporeme.reactions.get_by_id('ATPS4r_FWD_CPLX000-10_s').bounds = (0,0)
# # No glucose uptake from e
# for r in sporeme.reactions.query('GLCpts.*_s'):
#     print(r.id,r.reaction)
#     r.bounds = (0,0)
# Out:
# ATPS4r_REV_PORE-CPLX_s atp_s + h2o_s + 3.0 h_s --> -4.27350427350427e-6*sigma PORE-CPLX_s + adp_s + 4.0 h_c + pi_s
# ATPS4r_FWD_PORE-CPLX_s adp_s + 4.0 h_c + pi_s --> -4.27350427350427e-6*sigma PORE-CPLX_s + atp_s + h2o_s + 3.0 h_s

# %% [markdown]
# ### Change carbon source to glutamate

# %%
sporeme.reactions.get_by_id("EX_glc__D_e").bounds = (0,1000)
sporeme.reactions.get_by_id("EX_glu__L_e").bounds = (-2,1000)

# %% [markdown]
# ### Fixes

# %%
for r in sporeme.reactions:
    if r.objective_coefficient:
        r.objective_coefficient = 0
sporeme.reactions.get_by_id("dummy_reaction_FWD_SPONT_s").objective_coefficient = 1

# %% [markdown]
# ### Solve

# %%
solve_me_model(sporeme, max_mu = 0.1, min_mu = .05, using_soplex=False, precision = 1e-6,growth_key = 'sigma')
# Out:
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 51.828684 seconds
# Finished substituting S,lb,ub in 1.812127 seconds
# Finished makeME_LP in 0.254024 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Cold start
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =           6
#  sinf   =   2.08664766040671025527842282377517381E-0005
#  obj    =   0.00000000000000000000000000000000000
#                                0
#                 0
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 1 0.0 0.0 0.05 0.05 1
# Finished substituting S,lb,ub in 1.805378 seconds
# Finished makeME_LP in 0.254363 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Cold start
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   1.74836503691434896469128308684498207E-0004
# BFF26EA8A21897035A45F008CA10CBB3
#  BF26EA8A21897036
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 2 0.025 0.025 0.05 0.025 optimal
# Finished substituting S,lb,ub in 1.791984 seconds
# Finished makeME_LP in 0.254232 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =          22
#  sinf   =   1.57044195802915778808218715411225016E-0002
#  obj    =  -4.07105001484269280109031117448759766E-0038
# 3F82BB4C4FB3EF8CAB60EFB458829DB7
#  382BB4C4FB3EF8CB
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 3 0.025 0.025 0.037500000000000006 0.037500000000000006 1
# Finished substituting S,lb,ub in 1.803143 seconds
# Finished makeME_LP in 0.250566 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   7.73942865874222893664768878946936908E-0005
# BFF1449D7B81AEE1B03EDB1DC126AB29
#  BF1449D7B81AEE1B
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 4 0.03125 0.03125 0.037500000000000006 0.03125 optimal
# Finished substituting S,lb,ub in 1.783700 seconds
# Finished makeME_LP in 0.253577 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =         683
#  sinf   =   2.09205763409644966870159753070671666
#  obj    =  -1.49180943498445445949028263665631823E-0004
# 3FF238DAE8C09CC17FD162CC2A7582F6
#  3F238DAE8C09CC18
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 5 0.03125 0.03125 0.034375 0.034375 1
# Finished substituting S,lb,ub in 1.765290 seconds
# Finished makeME_LP in 0.249963 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU updat6 0.03125 0.03125 0.0328125 0.0328125 1
# e tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =          33
#  sinf   =  0.502501445200255996825562138726855231
#  obj    =  -3.55401169659382856894404279596034568E-0005
# 3FF02A21D1EDA4072E512630B43C7D17
#  3F02A21D1EDA4073
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# Finished substituting S,lb,ub in 1.777895 seconds
# Finished makeME_LP in 0.251969 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   2.10132767250521324951787052613906135E-0005
# BFEF608B5618CC7247B9D25C2A137DAE
#  BEF608B5618CC724
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 7 0.03203125 0.03203125 0.0328125 0.03203125 optimal
# Finished substituting S,lb,ub in 1.783203 seconds
# Finished makeME_LP in 0.254261 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =           3
#  sinf   =  0.102611368541143369364476529405443165
#  obj    =  -7.24176968755329070327938216809465939E-0006
# 3FEDE5FCA7E8978C8BD0521E6BA94062
#  3EDE5FCA7E8978C9
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 8 0.03203125 0.03203125 0.032421875 0.032421875 1
# Finished substituting S,lb,ub in 1.809977 seconds
# Finished makeME_LP in 0.253102 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   6.88326007477779115003908848556531572E-0006
# BFEDCDED81F4F74322D07B7F177D8176
#  BEDCDED81F4F7432
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 9 0.0322265625 0.0322265625 0.032421875 0.0322265625 optimal
# Finished substituting S,lb,ub in 1.811354 seconds
# Finished makeME_LP in 0.256148 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU updat10 0.0322265625 0.0322265625 0.03232421875 0.03232421875 1
# e tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =           2
#  sinf   =   2.64204772936608165646743557563578676E-0003
#  obj    =  -1.86436404059238107852119354306484741E-0007
# 3FE8905E7F3ECBBC279B4BCA0459F2F6
#  3E8905E7F3ECBBC2
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# Finished substituting S,lb,ub in 1.804785 seconds
# Finished makeME_LP in 0.255402 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   3.34877915571333377498673068151477447E-0006
# BFECC1772CF6E8881FDF2A09B02D27EE
#  BECC1772CF6E8882
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 11 0.032275390625 0.032275390625 0.03232421875 0.032275390625 optimal
# Finished substituting S,lb,ub in 1.817089 seconds
# Finished makeME_LP in 0.253913 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   1.58126266762481937551704869700666354E-0006
# BFEBA8778B08B0A4B14AB818F2025088
#  BEBA8778B08B0A4B
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 12 0.0322998046875 0.0322998046875 0.03232421875 0.0322998046875 optimal
# Finished substituting S,lb,ub in 1.781076 seconds
# Finished makeME_LP in 0.250957 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   6.97435680175176654381141667294903928E-0007
# BFEA766ED47AB420F71C4AA316895749
#  BEA766ED47AB420F
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 13 0.032312011718750006 0.032312011718750006 0.03232421875 0.032312011718750006 optimal
# Finished substituting S,lb,ub in 1.814089 seconds
# Finished makeME_LP in 0.254485 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   2.55505368339784345407507948737636170E-0007
# BFE91258C7E695B9266EC5E981D4E67C
#  BE91258C7E695B92
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 14 0.032318115234375 0.032318115234375 0.03232421875 0.032318115234375 optimal
# Finished substituting S,lb,ub in 1.802488 seconds
# Finished makeME_LP in 0.254845 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   3.45359144150747081781195701969253793E-0008
# BFE628A947694CD6DC35CD01743EF46B
#  BE628A947694CD6E
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 15 0.0323211669921875 0.0323211669921875 0.03232421875 0.0323211669921875 optimal
# Finished substituting S,lb,ub in 1.785336 seconds
# Finished makeME_LP in 0.254242 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU updat16 0.0323211669921875 0.0323211669921875 0.03232269287109375 0.03232269287109375 1
# e tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =           2
#  sinf   =   1.07570056006192105749317604922918433E-0003
#  obj    =  -7.59498867893837844963772314299517043E-0008
# 3FE74633C89D7EFA0869FB2B8C53A85B
#  3E74633C89D7EFA1
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# Finished substituting S,lb,ub in 1.809477 seconds
# Finished makeME_LP in 0.255692 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =           2
#  sinf   =   2.92520836342728781864784624894769507E-0004
#  obj    =  -2.07068966760014431602307222145695184E-0008
# 3FE563BDE509DBC8548789903A393E4C
#  3E563BDE509DBC85
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 17 0.0323211669921875 0.0323211669921875 0.032321929931640625 0.032321929931640625 1
# Bisection done in 303.253 seconds

# %%
sporeme.name = 'Spore model with spoIIIA-H - spoIIQ pore channel'
with open("./sporeme_solution_v4_proteomics_spoAQ_naive.pickle", "wb") as outfile:
    pickle.dump(sporeme, outfile)

# %% [markdown]
# ### Close specific reactions in the spore
# Sporulation allows bacteria to survive adverse conditions and is essential to the lifecycle of some obligate anaerobes. In Bacillus subtilis, the sporulation-specific sigma factors, σF, σE, σG, and σK, activate compartment-specific transcriptional programs that drive sporulation through its morphological stages
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4380625/

# %%
# From proteomics. ilvE = ybgE
gene_dictionary = pd.read_csv('../../building_data/gene_name_dictionary.csv',index_col=1)

deplete_genes = set(['pckA','purL','ilvB','ilvE','citZ','acsA','etfA','acoC','sigF','yxbC','lutC',
                  'argJ','hpf'])
deplete_genes -= set(['sigF']) # sigF and sigG are FS sigma factors
deplete_genes = deplete_genes | set(['sigE', 'sigKc', 'sigKn']) # sigE and sigK are MC sigma factors

deplete_genes = set(gene_dictionary.loc[deplete_genes]['locus_id'])

# %%
eliminate_genes = (deplete_genes)
len(eliminate_genes)
# Out:
# 15

# %%
# # From Eammon's paper.
# # https://www.science.org/doi/10.1126/sciadv.abd6385
# eliminate_genes = ['citB','citZ','icd','sucD','fumC','mdh']
# gene_dictionary.loc[eliminate_genes]['locus_id']

# %%
essentiality_df = pd.read_csv('../essentiality/essentiality_results.csv',index_col=0)
eliminate_ids = set(eliminate_genes) & set(essentiality_df.index)
essentiality_df.loc[eliminate_ids]
# Out:
#           response_me essentiality_me    response_m essentiality_m  \
# BSU06480     0.000000               0 -1.000000e+00              e
# BSU29680     0.000000               0 -1.302820e-10              0
# BSU25760    -1.000000               e           NaN            NaN
# BSU29140    -0.000028               0  0.000000e+00              0
# BSU26390    -1.000000               e           NaN            NaN
# BSU28310    -0.000009               0  0.000000e+00              0
# BSU30560     0.000000               0 -1.828217e-10              0
# BSU11200    -1.000000               e -1.000000e+00              e
# BSU15320    -1.000000               e           NaN            NaN
# BSU02390     0.000000               0  0.000000e+00              0
#
#          true_essentiality
# BSU06480                 0
# BSU29680                 0
# BSU25760                 0
# BSU29140                 0
# BSU26390                 0
# BSU28310                 0
# BSU30560                 0
# BSU11200                 0
# BSU15320                 0
# BSU02390                 0

# %%
for gene in eliminate_ids:
    r = 'translation_' + gene +'_s'
    if r not in sporeme.reactions:
        print(r+" not in model")
        continue
    print(r)
    rxn = sporeme.reactions.get_by_id(r)
    rxn.bounds = (0,0)
# Out:
# translation_BSU06480_s
# translation_BSU29680_s
# translation_BSU25760_s
# translation_BSU29140_s
# translation_BSU26390_s
# translation_BSU28310_s
# translation_BSU30560_s
# translation_BSU11200_s
# translation_BSU15320_s
# translation_BSU02390_s

# %% [markdown]
# ### Solve

# %%
solve_me_model(sporeme, max_mu = 0.1, min_mu = .05, using_soplex=False, precision = 1e-6,growth_key = 'sigma')
# Out:
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 50.625855 seconds
# Finished substituting S,lb,ub in 1.798457 seconds
# Finished makeME_LP in 0.257106 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Cold start
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =           4
#  sinf   =   5.02084689019694357858269463685714680E-0005
#  obj    =   0.00000000000000000000000000000000000
#                                0
#                 0
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 1 0.0 0.0 0.05 0.05 1
# Finished substituting S,lb,ub in 1.834623 seconds
# Finished makeME_LP in 0.246557 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Cold start
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =          12
#  sinf   =   5.63582911267040597057208359590941721E-0006
#  obj    =   0.00000000000000000000000000000000000
#                                0
#                 0
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 2 0.0 0.0 0.025 0.025 1
# Finished substituting S,lb,ub in 1.782122 seconds
# Finished makeME_LP in 0.253089 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Cold start
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   8.64152679883126001683803524477351483E-0005
# BFF16A73AFFE1D250BBE0FE51C988FBB
#  BF16A73AFFE1D251
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 3 0.0125 0.0125 0.025 0.0125 optimal
# Finished substituting S,lb,ub in 1.796041 seconds
# Finished makeME_LP in 0.253842 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =          32
#  sinf   =   4.64863663670720917445148928259626901E-0004
#  obj    =  -7.18808814435764644596796710634265350E-0039
# 3F803915DC7020F7763E5735114DBBCD
#  3803915DC7020F77
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 4 0.0125 0.0125 0.018750000000000003 0.018750000000000003 1
# Finished substituting S,lb,ub in 1.819964 seconds
# Finished makeME_LP in 0.255304 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   9.95958943751451302734956302077854548E-0005
# BFF1A1BC46FC6E23B97BEAA51850FC89
#  BF1A1BC46FC6E23C
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 5 0.015625 0.015625 0.018750000000000003 0.015625 optimal
# Finished substituting S,lb,ub in 1.827785 seconds
# Finished makeME_LP in 0.255669 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   5.39942622260618892560405989788149180E-0005
# BFF0C4EFCB934B7F543235B0ACE80265
#  BF0C4EFCB934B7F5
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 6 0.0171875 0.0171875 0.018750000000000003 0.0171875 optimal
# Finished substituting S,lb,ub in 1.825039 seconds
# Finished makeME_LP in 0.252285 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =           2
#  sinf   =   2.89479182049581720496716351932948075E-0002
#  obj    =  -1.90039299306453675242102218373663392E-0006
# 3FEBFE2203176C4667E3888FE46E062F
#  3EBFE2203176C466
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 7 0.0171875 0.0171875 0.017968750000000002 0.017968750000000002 1
# Finished substituting S,lb,ub in 1.789286 seconds
# Finished makeME_LP in 0.256737 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   2.61283932719574517295018098641861757E-0005
# BFEFB65C9837B609A4BA61EEEF87BBD5
#  BEFB65C9837B609A
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 8 0.017578125 0.017578125 0.017968750000000002 0.017578125 optimal
# Finished substituting S,lb,ub in 1.826603 seconds
# Finished makeME_LP in 0.255553 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   1.21338189052828491506689022369574156E-0005
# BFEE9724B5F38D36A22FD3FE6ED08AD8
#  BEE9724B5F38D36A
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 9 0.017773437500000003 0.017773437500000003 0.017968750000000002 0.017773437500000003 optimal
# Finished substituting S,lb,ub in 1.817243 seconds
# Finished makeME_LP in 0.257125 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   5.12160170899335200724808883382473469E-0006
# BFED57B472870A674F91F5C64BEA1B94
#  BED57B472870A675
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 10 0.017871093750000004 0.017871093750000004 0.017968750000000002 0.017871093750000004 optimal
# Finished substituting S,lb,ub in 1.821432 seconds
# Finished makeME_LP in 0.254598 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   1.61181844234261647347732344227369895E-0006
# BFEBB0AB51E852B6BC9CB718EDE6C4F4
#  BEBB0AB51E852B6C
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 11 0.017919921875 0.017919921875 0.017968750000000002 0.017919921875 optimal
# Finished substituting S,lb,ub in 1.802303 seconds
# Finished makeME_LP in 0.254252 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =           2
#  sinf   =   2.19350628526246104926633937168435460E-0003
#  obj    =  -1.43984758748343279257105024393411240E-0007
# 3FE83534754EC4C01D9ABA129BA4E999
#  3E83534754EC4C02
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 12 0.017919921875 0.017919921875 0.0179443359375 0.0179443359375 1
# Finished substituting S,lb,ub in 1.822100 seconds
# Finished makeME_LP in 0.253853 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   7.33992596135186622071471846978722557E-0007
# BFEA8A0F2C9CE4EE262D1357201B1D6A
#  BEA8A0F2C9CE4EE2
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 13 0.01793212890625 0.01793212890625 0.0179443359375 0.01793212890625 optimal
# Finished substituting S,lb,ub in 1.821032 seconds
# Finished makeME_LP in 0.251318 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   2.95022841607209318873315742606730733E-0007
# BFE93CC742DE1CAF5FF1E9504E2667BF
#  BE93CC742DE1CAF6
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 14 0.017938232421875 0.017938232421875 0.0179443359375 0.017938232421875 optimal
# Finished substituting S,lb,ub in 1.820315 seconds
# Finished makeME_LP in 0.255788 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   7.55237702009112487154165061878921086E-0008
# BFE7445F437559DC9272E9F7C6B0AE4B
#  BE7445F437559DC9
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 15 0.0179412841796875 0.0179412841796875 0.0179443359375 0.0179412841796875 optimal
# Finished substituting S,lb,ub in 1.796643 seconds
# Finished makeME_LP in 0.253719 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           1
#  ninf   =           2
#  sinf   =   5.21397375951984631860318282295086676E-0004
#  obj    =  -3.42293123247735376157535535157439088E-0008
# 3FE626070DC76456D1DF886B490B7215
#  3E626070DC76456D
#                                0
#                 0
# 80000000000000000000000000000000
#  8000000000000000
# 16 0.0179412841796875 0.0179412841796875 0.01794281005859375 0.01794281005859375 1
# Finished substituting S,lb,ub in 1.810431 seconds
# Finished makeME_LP in 0.255152 seconds
# Getting MINOS parameters from ME_NLP...
#  Allocating name1, name2
#  Allocating pi, rc, xn
#  Allocated pi, rc, xn
#  No Jacobian matrix since no nonlinear obj or constraints
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling miopt to set option: Maximize
#  Calling miopt to set option: Solution No
#  Calling miopti to set option New basis file to           11
#  Calling miopti to set option Save frequency to       500000
#  Calling miopti to set option Print level to            0
#  Calling miopti to set option Print frequency to       100000
#  Calling miopti to set option Scale option to            2
#  Calling miopti to set option Iteration limit to      2000000
#  Calling miopti to set option Expand frequency to       100000
#  46293E5939A08CEA
# 406293E5939A08CEA000000000000000
#  Calling mioptr to set option Penalty parameter to    100.00000000000000
#  Calling mioptr to set option LU factor tol to    10.000000000000000
#  Calling mioptr to set option LU update tol to    10.000000000000000
#  Calling mioptr to set option LU singularity tol to    1.0000000000000001E-030
#  Calling mioptr to set option Feasibility tol to    9.9999999999999995E-021
#  Calling mioptr to set option Optimality tol to    9.9999999999999995E-021
#  Calling mioptr to set option Unbounded step size to    1.0000000000000000E+030
# C0028000000000000000000000000000
#  C028000000000000
# C0028000000000000000000000000000
# C083D6329F1C35CA5000000000000000
#  C83D6329F1C35CA5
# C083D6329F1C35CA5000000000000000
# 4083D6329F1C35CA5000000000000000
#  483D6329F1C35CA5
# 4083D6329F1C35CA5000000000000000
#  Calling minoss. Warm start with provided basis (hs)
#
#  Quad MINOS finished.
#  inform =           0
#  ninf   =           0
#  sinf   =   0.00000000000000000000000000000000000
#  obj    =   2.06475244550700738633783535648665711E-0008
# BFE562B8C5DC495902A72344BA5B3D93
#  BE562B8C5DC49590
# BFFF0000000000000000000000000000
#  BFF0000000000000
# 3FFF0000000000000000000000000000
#  3FF0000000000000
# 17 0.017942047119140624 0.017942047119140624 0.01794281005859375 0.017942047119140624 optimal
# Bisection done in 416.58 seconds

# %%
sporeme.name = 'Spore model with proteomics constraints and spoIIIA-H - spoIIQ pore channel'
with open("./sporeme_solution_v4_proteomics_spoAQ.pickle", "wb") as outfile:
    pickle.dump(sporeme, outfile)

# %% [markdown]
# ## Properties

# %%
len(sporeme.metabolites.query('.*_s$')),\
len(sporeme.reactions.query('.*_s$')),\
len(sporeme.metabolites.query('protein_BSU\d*_s$'))
# Out:
# (3201, 5013, 733)

# %%
len(set(sporeme.metabolites) - set(sporeme.metabolites.query('.*_s$'))),\
len(set(sporeme.reactions) - set(sporeme.reactions.query('.*_s$'))),\
len(sporeme.metabolites.query('protein_BSU\d*[^s]$'))
# Out:
# (4239, 6231, 974)

# %%
len(sporeme.metabolites),\
len(sporeme.reactions),\
len(sporeme.metabolites.query('protein_BSU\d*_*s*$'))
# Out:
# (7440, 11244, 1707)

# %%
def get_breakdown(me,field):
    count = {}
    for instance in getattr(me,field):
        instance_type = instance.__class__.__name__
        if instance_type not in count.keys():
            count[instance_type] = 0
        count[instance_type] += 1
    return pd.DataFrame.from_dict({'count':count})

# %%
get_breakdown(sporeme,'metabolites').sort_values('count').plot.bar()
# Out:
# <AxesSubplot:>

# %%
get_breakdown(sporeme,'reactions').sort_values('count').plot.bar()
# Out:
# <AxesSubplot:>

# %%
d = {}
for r in sporeme.reactions:
    try:
        rxn = r.reaction
    except:
        rxn = ''
    d[r.id] = {
        'lower_bound' : r.lower_bound,
        'upper_bound' : r.upper_bound,
        'reaction' : rxn,
        'subsystem' : r.subsystem,
        'flux' : sporeme.solution.x_dict[r.id]
    }

# %%
pd.DataFrame.from_dict(d).T.to_csv('Supplementary Files/Supplementary File 1.csv')

# %% [markdown]
# ### Summary of the model

# %%
df = pd.read_csv("../../iYO844_summary.csv",index_col=0)
df.head()
# Out:
#                                                       name  \
# 23CN2P1  2  3  cyclic nucleotide 2  phosphodiesterase  ...
# 23CN2P2  2  3  cyclic nucleotide 2  phosphodiesterase  ...
# 23CN2P3  2  3  cyclic nucleotide 2  phosphodiesterase  ...
# 23CN2P4  2  3  cyclic nucleotide 2  phosphodiesterase  ...
# 26DPAi                               Dipicolinate synthase
#
#                                           reaction  \
# 23CN2P1          23camp_c + h2o_c <=> 3amp_c + h_c
# 23CN2P2          23cump_c + h2o_c <=> 3ump_c + h_c
# 23CN2P3          23ccmp_c + h2o_c <=> 3cmp_c + h_c
# 23CN2P4          23cgmp_c + h2o_c <=> 3gmp_c + h_c
# 26DPAi   23dhdp_c + nad_c --> DPA_c + h_c + nadh_c
#
#                                        reaction_with_names  \
# 23CN2P1  2',3'-Cyclic AMP + H2O H2O <=> 3  AMP C10H12N5...
# 23CN2P2  2',3'-Cyclic UMP + H2O H2O <=> 3  UMP C9H11N2O...
# 23CN2P3  2',3'-Cyclic CMP + H2O H2O <=> 3  CMP C9H12N3O...
# 23CN2P4  2',3'-Cyclic GMP + H2O H2O <=> Guanosine 3  ph...
# 26DPAi   2,3-Dihydrodipicolinate + Nicotinamide adenine...
#
#                          genes
# 23CN2P1               BSU07840
# 23CN2P2               BSU07840
# 23CN2P3               BSU07840
# 23CN2P4               BSU07840
# 26DPAi   BSU16730 and BSU16740

# %%
d = {}
for r in sporeme.reactions:
    if not isinstance(r, cobrame.core.reaction.MetabolicReaction):
        continue
    if r.id[-2:] == "_s":
        cell = "spore"
    else:
        cell = "mother"
    baseid = re.split("_FWD_|_REV_",r.id)[0]
    sign = 1 if "FWD" in r.id else -1
    flux = sign * sporeme.solution.x_dict[r.id]
    if baseid not in d:
        d[baseid] = {
            "spore" : 0,
            "mother" : 0
        }
    d[baseid][cell] += flux
flux = pd.DataFrame.from_dict(d).T

# %%
df["spore"] = flux["spore"]
df["mother"] = flux["mother"]
df.head()
df = df.fillna({"spore":0, "mother":0})
df = df.fillna("")
df.to_csv("sporeme_metabolic_flux_summary.csv")

# %%
df
# Out:
#                                                         name  \
# 23CN2P1    2  3  cyclic nucleotide 2  phosphodiesterase  ...
# 23CN2P2    2  3  cyclic nucleotide 2  phosphodiesterase  ...
# 23CN2P3    2  3  cyclic nucleotide 2  phosphodiesterase  ...
# 23CN2P4    2  3  cyclic nucleotide 2  phosphodiesterase  ...
# 26DPAi                                 Dipicolinate synthase
# ...                                                      ...
# CU2abc1
# COBALTt5                  Cobalt(II) transport via diffusion
# ETOHtex                      Ethanol transport via diffusion
# EX_cbl1_e
# CBLtex
#
#                                                     reaction  \
# 23CN2P1                    23camp_c + h2o_c <=> 3amp_c + h_c
# 23CN2P2                    23cump_c + h2o_c <=> 3ump_c + h_c
# 23CN2P3                    23ccmp_c + h2o_c <=> 3cmp_c + h_c
# 23CN2P4                    23cgmp_c + h2o_c <=> 3gmp_c + h_c
# 26DPAi             23dhdp_c + nad_c --> DPA_c + h_c + nadh_c
# ...                                                      ...
# CU2abc1    atp_c + cu2_e + h2o_c --> adp_c + cu2_c + h_c ...
# COBALTt5                             cobalt2_e --> cobalt2_c
# ETOHtex                                    etoh_e --> etoh_c
# EX_cbl1_e                                        cbl1_e <=>
# CBLtex                                     cbl1_e --> cbl1_c
#
#                                          reaction_with_names  \
# 23CN2P1    2',3'-Cyclic AMP + H2O H2O <=> 3  AMP C10H12N5...
# 23CN2P2    2',3'-Cyclic UMP + H2O H2O <=> 3  UMP C9H11N2O...
# 23CN2P3    2',3'-Cyclic CMP + H2O H2O <=> 3  CMP C9H12N3O...
# 23CN2P4    2',3'-Cyclic GMP + H2O H2O <=> Guanosine 3  ph...
# 26DPAi     2,3-Dihydrodipicolinate + Nicotinamide adenine...
# ...                                                      ...
# CU2abc1    ATP C10H12N5O13P3 + Copper + H2O H2O --> ADP C...
# COBALTt5                                       Co2+ --> Co2+
# ETOHtex                                  Ethanol --> Ethanol
# EX_cbl1_e                                               <=>
# CBLtex                                                  -->
#
#                            genes  spore        mother
# 23CN2P1                 BSU07840    0.0  0.000000e+00
# 23CN2P2                 BSU07840    0.0  0.000000e+00
# 23CN2P3                 BSU07840    0.0  0.000000e+00
# 23CN2P4                 BSU07840    0.0  0.000000e+00
# 26DPAi     BSU16730 and BSU16740    0.0  0.000000e+00
# ...                          ...    ...           ...
# CU2abc1                 BSU33500    0.0  0.000000e+00
# COBALTt5                            0.0  2.258917e-09
# ETOHtex                             0.0  0.000000e+00
# EX_cbl1_e                           0.0  0.000000e+00
# CBLtex                  BSU33170    0.0  1.417260e-10
#
# [1247 rows x 6 columns]
